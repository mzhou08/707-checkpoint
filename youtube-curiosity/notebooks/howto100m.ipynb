# %%
import json
import matplotlib.pyplot as plt

import matplotlib.image as mpimg
import numpy as np
import pprint

# %%
with open("playground/data/howto100m/caption.json") as hand:
    ht100m = json.load(hand)
    pprint.pprint(len(ht100m))
# Out:
# 1238911

# %%
print(
    list(ht100m.keys())[:10]
)
# Out:
# ['nVbIUDjzWY4', 'CTPAZ2euJ2Q', 'rwmt7Cbuvfs', 'HnTLh99gcxY', 'EyP3HVhg1u0', 'w6zbbdK1ewY', 'RAidUDTPZ-k', 'nssig0FNZVU', 'm2YyhYyleII', 'u5B1RAufWVM']

# %%
pprintf(ht100m['nVbIUDjzWY4'])
# Out:
# {'end': [18.05,
#          20.6,
#          26.36,
#          29.36,
#          32.0,
#          35.33,
#          37.69,
#          40.67,
#          42.65,
#          44.57,
#          47.08,
#          48.89,
#          51.19,
#          53.96,
#          57.22,
#          59.23,
#          60.58,
#          62.78,
#          64.15,
#          66.35,
#          68.21000000000001,
#          69.83,
#          71.81,
#          73.82,
#          76.28,
#          77.78,
#          79.64,
#          81.2,
#          82.97,
#          86.06,
#          87.95,
#          89.3,
#          91.58,
#          93.11,
#          96.95,
#          99.41,
#          102.4,
#          104.65,
#          106.73,
#          108.95,
#          110.63,
#          114.83,
#          118.31,
#          120.47,
#          123.8,
#          125.54,
#          127.7,
#          130.0,
#          131.84,
#          132.62,
#          134.45,
#          136.06,
#          138.53,
#          140.29,
# ...
